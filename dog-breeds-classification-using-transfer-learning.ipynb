# %%
#import libraries
import numpy as np
import os
import cv2
import itertools
import matplotlib.pyplot as plt
import tensorflow as tf
from glob import glob
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.callbacks import Callback, ReduceLROnPlateau, ModelCheckpoint, CSVLogger
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.utils import shuffle

# %%
path = "/kaggle/input/120-dog-breeds-breed-classification/Images"

# %%
#parameters
IMAGE_SIZE = [224, 224]
channel = 3
num_class = 120
batch_size = 128

# %% [markdown]
# # Basic Function

# %%
#get directory of images
def get_labels(path):
  files = os.listdir(path)
  return files

# %%
#split the name and unique address
def get_splited_name(labels):
  splited_list = []
  labels_list = []
  for i in labels:
    splited = i.split('-')
    labels_list.append(splited[-1])
    splited_list.append(splited)
  
  return splited_list, labels_list

# %%
#create dictionary for name and unique address
def get_name_index(splited_list):
  new_list = [{item[0]: item[1]} for item in splited_list]
  return new_list

# %%
folder = get_labels(path)
splited_list, labels_list = get_splited_name(folder)
index_list = get_name_index(splited_list)

# %%
labels_list
# Out:
# ['otterhound',
#  'cocker_spaniel',
#  'Brittany_spaniel',
#  'Afghan_hound',
#  'Maltese_dog',
#  'schipperke',
#  'Irish_setter',
#  'Pekinese',
#  'golden_retriever',
#  'vizsla',
#  'Welsh_springer_spaniel',
#  'Staffordshire_bullterrier',
#  'Border_collie',
#  'Irish_terrier',
#  'Eskimo_dog',
#  'pug',
#  'kelpie',
#  'Yorkshire_terrier',
#  'Tibetan_terrier',
#  'Walker_hound',
#  'affenpinscher',
#  'Cardigan',
#  'English_springer',
#  'English_foxhound',
#  'West_Highland_white_terrier',
#  'Lakeland_terrier',
#  'Rhodesian_ridgeback',
#  'Gordon_setter',
#  'Lhasa',
#  'coated_retriever',
#  'beagle',
#  'Tibetan_mastiff',
#  'Sussex_spaniel',
#  'Saint_Bernard',
#  'toy_terrier',
#  'standard_poodle',
#  'Bernese_mountain_dog',
#  'Pomeranian',
#  'Ibizan_hound',
#  'redbone',
#  'toy_poodle',
#  'basset',
#  'Scottish_deerhound',
#  'miniature_pinscher',
#  'basenji',
#  'Border_terrier',
#  'Bedlington_terrier',
#  'Kerry_blue_terrier',
#  'Weimaraner',
#  'English_setter',
#  'bluetick',
#  'Boston_bull',
#  'Italian_greyhound',
#  'Dandie_Dinmont',
#  'Airedale',
#  'Irish_water_spaniel',
#  'Norfolk_terrier',
#  'haired_fox_terrier',
#  'French_bulldog',
#  'coated_wheaten_terrier',
#  'komondor',
#  'African_hunting_dog',
#  'Siberian_husky',
#  'Newfoundland',
#  'Bouvier_des_Flandres',
#  'Saluki',
#  'Shetland_sheepdog',
#  'collie',
#  'Rottweiler',
#  'silky_terrier',
#  'Norwegian_elkhound',
#  'Chihuahua',
#  'Leonberg',
#  'Norwich_terrier',
#  'cairn',
#  'boxer',
#  'borzoi',
#  'dhole',
#  'Samoyed',
#  'German_shepherd',
#  'Labrador_retriever',
#  'Blenheim_spaniel',
#  'groenendael',
#  'Doberman',
#  'Great_Dane',
#  'coated_retriever',
#  'Appenzeller',
#  'Tzu',
#  'Japanese_spaniel',
#  'Greater_Swiss_Mountain_dog',
#  'tan_coonhound',
#  'dingo',
#  'Great_Pyrenees',
#  'whippet',
#  'keeshond',
#  'malinois',
#  'American_Staffordshire_terrier',
#  'Mexican_hairless',
#  'giant_schnauzer',
#  'Brabancon_griffon',
#  'kuvasz',
#  'miniature_poodle',
#  'Irish_wolfhound',
#  'briard',
#  'clumber',
#  'standard_schnauzer',
#  'bull_mastiff',
#  'malamute',
#  'Sealyham_terrier',
#  'EntleBucher',
#  'chow',
#  'papillon',
#  'Pembroke',
#  'haired_pointer',
#  'Old_English_sheepdog',
#  'Chesapeake_Bay_retriever',
#  'Scotch_terrier',
#  'Australian_terrier',
#  'miniature_schnauzer',
#  'bloodhound']

# %%
index_list
# Out:
# [{'n02091635': 'otterhound'},
#  {'n02102318': 'cocker_spaniel'},
#  {'n02101388': 'Brittany_spaniel'},
#  {'n02088094': 'Afghan_hound'},
#  {'n02085936': 'Maltese_dog'},
#  {'n02104365': 'schipperke'},
#  {'n02100877': 'Irish_setter'},
#  {'n02086079': 'Pekinese'},
#  {'n02099601': 'golden_retriever'},
#  {'n02100583': 'vizsla'},
#  {'n02102177': 'Welsh_springer_spaniel'},
#  {'n02093256': 'Staffordshire_bullterrier'},
#  {'n02106166': 'Border_collie'},
#  {'n02093991': 'Irish_terrier'},
#  {'n02109961': 'Eskimo_dog'},
#  {'n02110958': 'pug'},
#  {'n02105412': 'kelpie'},
#  {'n02094433': 'Yorkshire_terrier'},
#  {'n02097474': 'Tibetan_terrier'},
#  {'n02089867': 'Walker_hound'},
#  {'n02110627': 'affenpinscher'},
#  {'n02113186': 'Cardigan'},
#  {'n02102040': 'English_springer'},
#  {'n02089973': 'English_foxhound'},
#  {'n02098286': 'West_Highland_white_terrier'},
#  {'n02095570': 'Lakeland_terrier'},
#  {'n02087394': 'Rhodesian_ridgeback'},
#  {'n02101006': 'Gordon_setter'},
#  {'n02098413': 'Lhasa'},
#  {'n02099429': 'curly'},
#  {'n02088364': 'beagle'},
#  {'n02108551': 'Tibetan_mastiff'},
#  {'n02102480': 'Sussex_spaniel'},
#  {'n02109525': 'Saint_Bernard'},
#  {'n02087046': 'toy_terrier'},
#  {'n02113799': 'standard_poodle'},
#  {'n02107683': 'Bernese_mountain_dog'},
#  {'n02112018': 'Pomeranian'},
#  {'n02091244': 'Ibizan_hound'},
#  {'n02090379': 'redbone'},
#  {'n02113624': 'toy_poodle'},
#  {'n02088238': 'basset'},
#  {'n02092002': 'Scottish_deerhound'},
#  {'n02107312': 'miniature_pinscher'},
#  {'n02110806': 'basenji'},
#  {'n02093754': 'Border_terrier'},
#  {'n02093647': 'Bedlington_terrier'},
#  {'n02093859': 'Kerry_blue_terrier'},
#  {'n02092339': 'Weimaraner'},
#  {'n02100735': 'English_setter'},
#  {'n02088632': 'bluetick'},
#  {'n02096585': 'Boston_bull'},
#  {'n02091032': 'Italian_greyhound'},
#  {'n02096437': 'Dandie_Dinmont'},
#  {'n02096051': 'Airedale'},
#  {'n02102973': 'Irish_water_spaniel'},
#  {'n02094114': 'Norfolk_terrier'},
#  {'n02095314': 'wire'},
#  {'n02108915': 'French_bulldog'},
#  {'n02098105': 'soft'},
#  {'n02105505': 'komondor'},
#  {'n02116738': 'African_hunting_dog'},
#  {'n02110185': 'Siberian_husky'},
#  {'n02111277': 'Newfoundland'},
#  {'n02106382': 'Bouvier_des_Flandres'},
#  {'n02091831': 'Saluki'},
#  {'n02105855': 'Shetland_sheepdog'},
#  {'n02106030': 'collie'},
#  {'n02106550': 'Rottweiler'},
#  {'n02097658': 'silky_terrier'},
#  {'n02091467': 'Norwegian_elkhound'},
#  {'n02085620': 'Chihuahua'},
#  {'n02111129': 'Leonberg'},
#  {'n02094258': 'Norwich_terrier'},
#  {'n02096177': 'cairn'},
#  {'n02108089': 'boxer'},
#  {'n02090622': 'borzoi'},
#  {'n02115913': 'dhole'},
#  {'n02111889': 'Samoyed'},
#  {'n02106662': 'German_shepherd'},
#  {'n02099712': 'Labrador_retriever'},
#  {'n02086646': 'Blenheim_spaniel'},
#  {'n02105056': 'groenendael'},
#  {'n02107142': 'Doberman'},
#  {'n02109047': 'Great_Dane'},
#  {'n02099267': 'flat'},
#  {'n02107908': 'Appenzeller'},
#  {'n02086240': 'Shih'},
#  {'n02085782': 'Japanese_spaniel'},
#  {'n02107574': 'Greater_Swiss_Mountain_dog'},
#  {'n02089078': 'black'},
#  {'n02115641': 'dingo'},
#  {'n02111500': 'Great_Pyrenees'},
#  {'n02091134': 'whippet'},
#  {'n02112350': 'keeshond'},
#  {'n02105162': 'malinois'},
#  {'n02093428': 'American_Staffordshire_terrier'},
#  {'n02113978': 'Mexican_hairless'},
#  {'n02097130': 'giant_schnauzer'},
#  {'n02112706': 'Brabancon_griffon'},
#  {'n02104029': 'kuvasz'},
#  {'n02113712': 'miniature_poodle'},
#  {'n02090721': 'Irish_wolfhound'},
#  {'n02105251': 'briard'},
#  {'n02101556': 'clumber'},
#  {'n02097209': 'standard_schnauzer'},
#  {'n02108422': 'bull_mastiff'},
#  {'n02110063': 'malamute'},
#  {'n02095889': 'Sealyham_terrier'},
#  {'n02108000': 'EntleBucher'},
#  {'n02112137': 'chow'},
#  {'n02086910': 'papillon'},
#  {'n02113023': 'Pembroke'},
#  {'n02100236': 'German_short'},
#  {'n02105641': 'Old_English_sheepdog'},
#  {'n02099849': 'Chesapeake_Bay_retriever'},
#  {'n02097298': 'Scotch_terrier'},
#  {'n02096294': 'Australian_terrier'},
#  {'n02097047': 'miniature_schnauzer'},
#  {'n02088466': 'bloodhound'}]

# %%
num_classes = len(index_list)

# %%
num_classes
# Out:
# 120

# %% [markdown]
# # Data Pipeline

# %%
def load_data(path, split=0.2):
  images = shuffle(glob(os.path.join(path,"*","*.jpg")))
  split_size = int(len(images)*split)
  #split data
  train_data, valid_data = train_test_split(images, test_size=split_size, random_state=42)
  train_data, test_data = train_test_split(train_data, test_size=split_size, random_state=42)

  return train_data, valid_data, test_data

# %%
train_data, valid_data, test_data = load_data(path)

# %%
print(f'train data: {len(train_data)}')
print(f'test data: {len(test_data)}')
print(f'valid data: {len(valid_data)}')
# Out:
# train data: 12348
# test data: 4116
# valid data: 4116

# %%
train_data[0]
# Out:
# '/kaggle/input/120-dog-breeds-breed-classification/Images/n02099601-golden_retriever/n02099601_3111.jpg'

# %%
def process_image(path):
    #decode the path
    path = path.decode()
    #read image
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    #resize the image
    image = cv2.resize(image, [W, H])
    #scale the image
    image = image / 255.0
    #change the data type of image
    image = image.astype(np.float32)

    #labeling the image
    class_name = path.split("/")[-2].split('-')[-1]
    class_idx = labels_list.index(class_name)
    class_idx = np.array(class_idx, dtype=np.int32)

    return image, class_idx

# %%
def parse(path):
    image, labels = tf.numpy_function(process_image, [path], (tf.float32, tf.int32))
    labels = tf.one_hot(labels, num_class)
    image.set_shape([224, 224, 3])
    labels.set_shape(num_class)
  
    return image, labels

# %%
#tensorflow dataset
def tf_dataset(images, batch=64):
    dataset = tf.data.Dataset.from_tensor_slices((images))
    dataset = dataset.map(parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(64)
    return dataset

# %% [markdown]
# # Model

# %%
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
#freeze training existing layer
for layer in vgg.layers:
  layer.trainable = False

# %%
#build our layers
x = Flatten()(vgg.output)

# %%
#set last layer
prediction_layer = Dense(num_classes, activation='softmax' )(x)
#declare the model
model = Model(inputs=vgg.input, outputs=prediction_layer)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 120)               3010680
#
# =================================================================
# Total params: 17,725,368
# Trainable params: 3,010,680
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model_path = "/kaggle/working/dog-breed.h5"
csv_path = "/kaggle/working/dog-breed.csv"

# %%
#initalize callbacks
callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    CSVLogger(csv_path),
    ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=5, min_lr=1e-7, verbose=1)
]

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#tensor dataset
train_df = tf_dataset(train_data)
test_df = tf_dataset(test_data)
valid_df = tf_dataset(valid_data)

# %%
#training
model.fit(
    train_df,
    validation_data=valid_df,
    epochs=20,
    batch_size=128,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 97/97 [==============================] - ETA: 0s - loss: 4.1819 - accuracy: 0.1623
# Epoch 1: val_loss improved from inf to 3.33932, saving model to /kaggle/working/dog-breed.h5
# 97/97 [==============================] - 142s 1s/step - loss: 4.1819 - accuracy: 0.1623 - val_loss: 3.3393 - val_accuracy: 0.2490 - lr: 0.0010
# Epoch 2/20
# 97/97 [==============================] - ETA: 0s - loss: 1.1735 - accuracy: 0.7336
# Epoch 2: val_loss improved from 3.33932 to 3.19880, saving model to /kaggle/working/dog-breed.h5
# 97/97 [==============================] - 95s 980ms/step - loss: 1.1735 - accuracy: 0.7336 - val_loss: 3.1988 - val_accuracy: 0.2777 - lr: 0.0010
# Epoch 3/20
# 97/97 [==============================] - ETA: 0s - loss: 0.5220 - accuracy: 0.9076
# Epoch 3: val_loss did not improve from 3.19880
# 97/97 [==============================] - 94s 970ms/step - loss: 0.5220 - accuracy: 0.9076 - val_loss: 3.3095 - val_accuracy: 0.2728 - lr: 0.0010
# Epoch 4/20
# 97/97 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.9555
# Epoch 4: val_loss did not improve from 3.19880
# 97/97 [==============================] - 96s 981ms/step - loss: 0.2960 - accuracy: 0.9555 - val_loss: 3.4168 - val_accuracy: 0.2813 - lr: 0.0010
# Epoch 5/20
# 97/97 [==============================] - ETA: 0s - loss: 0.1810 - accuracy: 0.9739
# Epoch 5: val_loss did not improve from 3.19880
# 97/97 [==============================] - 96s 980ms/step - loss: 0.1810 - accuracy: 0.9739 - val_loss: 3.3538 - val_accuracy: 0.2821 - lr: 0.0010
# Epoch 6/20
# 97/97 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9871
# Epoch 6: val_loss did not improve from 3.19880
# 97/97 [==============================] - 94s 967ms/step - loss: 0.1132 - accuracy: 0.9871 - val_loss: 3.2512 - val_accuracy: 0.2979 - lr: 0.0010
# Epoch 7/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9911
# Epoch 7: val_loss did not improve from 3.19880
# 97/97 [==============================] - 94s 961ms/step - loss: 0.0823 - accuracy: 0.9911 - val_loss: 3.4184 - val_accuracy: 0.2954 - lr: 0.0010
# Epoch 8/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9929
# Epoch 8: val_loss did not improve from 3.19880
# 97/97 [==============================] - 95s 974ms/step - loss: 0.0658 - accuracy: 0.9929 - val_loss: 3.2453 - val_accuracy: 0.3282 - lr: 0.0010
# Epoch 9/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9944
# Epoch 9: val_loss did not improve from 3.19880
# 97/97 [==============================] - 94s 968ms/step - loss: 0.0522 - accuracy: 0.9944 - val_loss: 3.3355 - val_accuracy: 0.3112 - lr: 0.0010
# Epoch 10/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9955
# Epoch 10: val_loss improved from 3.19880 to 3.09719, saving model to /kaggle/working/dog-breed.h5
# 97/97 [==============================] - 95s 976ms/step - loss: 0.0446 - accuracy: 0.9955 - val_loss: 3.0972 - val_accuracy: 0.3345 - lr: 0.0010
# Epoch 11/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9963
# Epoch 11: val_loss improved from 3.09719 to 3.08941, saving model to /kaggle/working/dog-breed.h5
# 97/97 [==============================] - 95s 975ms/step - loss: 0.0380 - accuracy: 0.9963 - val_loss: 3.0894 - val_accuracy: 0.3345 - lr: 0.0010
# Epoch 12/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0330 - accuracy: 0.9965
# Epoch 12: val_loss did not improve from 3.08941
# 97/97 [==============================] - 93s 960ms/step - loss: 0.0330 - accuracy: 0.9965 - val_loss: 3.1354 - val_accuracy: 0.3348 - lr: 0.0010
# Epoch 13/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9967
# Epoch 13: val_loss did not improve from 3.08941
# 97/97 [==============================] - 94s 964ms/step - loss: 0.0342 - accuracy: 0.9967 - val_loss: 3.1565 - val_accuracy: 0.3353 - lr: 0.0010
# Epoch 14/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0340 - accuracy: 0.9964
# Epoch 14: val_loss did not improve from 3.08941
# 97/97 [==============================] - 95s 974ms/step - loss: 0.0340 - accuracy: 0.9964 - val_loss: 3.2217 - val_accuracy: 0.3365 - lr: 0.0010
# Epoch 15/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9968
# Epoch 15: val_loss did not improve from 3.08941
# 97/97 [==============================] - 93s 953ms/step - loss: 0.0357 - accuracy: 0.9968 - val_loss: 3.2644 - val_accuracy: 0.3331 - lr: 0.0010
# Epoch 16/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9965
# Epoch 16: val_loss did not improve from 3.08941
# 97/97 [==============================] - 93s 953ms/step - loss: 0.0348 - accuracy: 0.9965 - val_loss: 3.3105 - val_accuracy: 0.3328 - lr: 0.0010
# Epoch 17/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9967
# Epoch 17: val_loss did not improve from 3.08941
# 97/97 [==============================] - 93s 956ms/step - loss: 0.0359 - accuracy: 0.9967 - val_loss: 3.3475 - val_accuracy: 0.3307 - lr: 0.0010
# Epoch 18/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9968
# Epoch 18: val_loss did not improve from 3.08941
# 97/97 [==============================] - 93s 955ms/step - loss: 0.0356 - accuracy: 0.9968 - val_loss: 3.3810 - val_accuracy: 0.3285 - lr: 0.0010
# Epoch 19/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9968
# Epoch 19: val_loss did not improve from 3.08941
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 97/97 [==============================] - 95s 974ms/step - loss: 0.0360 - accuracy: 0.9968 - val_loss: 3.3617 - val_accuracy: 0.3275 - lr: 0.0010
# Epoch 20/20
# 97/97 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9971
# Epoch 20: val_loss improved from 3.08941 to 3.03715, saving model to /kaggle/working/dog-breed.h5
# 97/97 [==============================] - 95s 975ms/step - loss: 0.0239 - accuracy: 0.9971 - val_loss: 3.0371 - val_accuracy: 0.3513 - lr: 1.0000e-04

# %% [markdown]
# # Evaluate the model

# %%
model.evaluate(test_df)
# Out:
# 33/33 [==============================] - 25s 733ms/step - loss: 3.0970 - accuracy: 0.3414
# [3.0970287322998047, 0.34135082364082336]

# %%
#function for get labels of test set
def get_test_data_class(test_path):
  names = []
  for i in test_path:
    name = i.split("/")[-2].split('-')[-1]
    name_idx = labels_list.index(name)
    names.append(name_idx)
  names = np.array(names, dtype=np.int32)
  return names

# %%
classes = get_test_data_class(test_data)

# %% [markdown]
# # test the model

# %%
#image and name
test_data[0]
# Out:
# '/kaggle/input/120-dog-breeds-breed-classification/Images/n02097658-silky_terrier/n02097658_611.jpg'

# %%
#read the image 
img = cv2.imread(test_data[0], cv2.IMREAD_COLOR)
plt.imshow(img)

# %%
img_new = cv2.resize(img, (224,224))
img = np.array(img_new).reshape(-1, 224, 224, 3)

# %%
img = img.astype('float32')
img /= 255

# %%
pred = model.predict(img, verbose=0)
pred
# Out:
# array([[6.2545361e-05, 4.6886817e-07, 1.6001648e-07, 1.8747527e-05,
#         1.6066760e-07, 4.1692134e-09, 3.4124372e-04, 6.7368596e-08,
#         2.6572106e-06, 1.5544609e-08, 2.6909829e-04, 9.6501367e-09,
#         4.7388943e-07, 5.6038652e-06, 2.9340246e-08, 5.4430024e-07,
#         7.1185276e-08, 2.0450104e-02, 2.6413065e-04, 6.4762158e-12,
#         7.5081494e-05, 5.7680341e-09, 8.3198947e-06, 6.9092856e-08,
#         2.4291186e-08, 2.2729932e-06, 1.7702874e-05, 5.1317796e-02,
#         2.0021846e-04, 2.8802901e-06, 1.7103770e-06, 1.0641897e-05,
#         3.2930984e-04, 1.3380447e-06, 2.5428328e-05, 3.3264823e-05,
#         3.0286767e-04, 7.6638273e-08, 1.2311395e-08, 5.0286690e-06,
#         6.5118156e-06, 4.1821517e-05, 2.7263175e-06, 4.4681277e-04,
#         4.9203544e-07, 5.9175462e-04, 8.8662631e-07, 6.8916492e-08,
#         7.5375603e-08, 8.6966529e-06, 1.6646844e-05, 7.7599061e-06,
#         1.0526995e-07, 2.5705691e-02, 7.1981963e-06, 3.0378264e-06,
#         2.7215790e-06, 7.8218129e-08, 3.9514634e-05, 2.2506323e-07,
#         5.0293977e-08, 1.1895858e-04, 5.5578982e-07, 3.8927777e-05,
#         2.2417394e-06, 1.7504466e-06, 4.5989259e-06, 7.6063779e-06,
#         1.8394398e-04, 7.3088294e-01, 2.3583365e-07, 1.8360282e-05,
#         3.6398840e-05, 1.0563428e-02, 8.2675815e-06, 1.3170214e-06,
#         5.6118733e-07, 7.2618839e-10, 4.9714999e-10, 1.3945273e-05,
#         2.1728916e-07, 7.4014624e-06, 1.0043690e-06, 1.9334819e-05,
#         1.9755480e-07, 6.6754851e-09, 3.3572144e-07, 4.0852316e-04,
#         3.9406332e-05, 1.1782815e-04, 3.0082358e-06, 1.7330709e-07,
#         8.7136174e-09, 2.6668718e-07, 2.1992944e-08, 5.2690024e-07,
#         7.1264035e-09, 2.0385398e-06, 7.8251149e-05, 3.1019224e-06,
#         2.2714535e-09, 9.8238263e-05, 7.4942429e-05, 2.9371408e-04,
#         2.0618860e-05, 5.7902542e-04, 3.5845568e-07, 9.2463160e-06,
#         1.5439978e-06, 2.0726426e-05, 3.2976551e-08, 1.5668748e-03,
#         1.3129331e-06, 1.8448841e-06, 8.6711864e-08, 2.9535852e-09,
#         5.3098928e-03, 1.4875957e-01, 6.2692030e-05, 4.9387268e-07]],
#       dtype=float32)

# %%
val = np.argmax(pred)
val
# Out:
# 69

# %%
name = int(val)
labels_list[name]
# Out:
# 'silky_terrier'

# %%
sample_test = test_data[1:100]

# %%
prediction_name = []

# %%
for img in range(len(sample_test)):
    image = cv2.imread(sample_test[img], cv2.IMREAD_COLOR)
    img_new = cv2.resize(image, (224,224))
    img_new = np.array(img_new).reshape(-1, 224, 224, 3)
    img_new = img_new.astype('float32')
    img_new /= 255  
    pred = model.predict(img_new, verbose=0)
    val = np.argmax(pred)
    name = labels_list[val]
    prediction_name.append(name)

# %%
fig, axs = plt.subplots(10, 10, figsize=(10, 10))
axs = axs.flatten()
for i in range(100):
    img = cv2.imread(sample_test[i], cv2.IMREAD_COLOR)
    axs[i].plot(img)
    axs[i].set_title(prediction_name[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_24/2622473025.py in <module>
#       3 for i in range(100):
#       4     img = cv2.imread(sample_test[i], cv2.IMREAD_COLOR)
# ----> 5     axs[i].plot(img)
#       6     axs[i].set_title(prediction_name[i])
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1633         """
#    1634         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1635         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1636         for line in lines:
#    1637             self.add_line(line)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
# --> 501             raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                              f"shapes {x.shape} and {y.shape}")
#     503         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2D, but have shapes (333,) and (333, 500, 3)

# %%
sample_test[1]
# Out:
# '/kaggle/input/120-dog-breeds-breed-classification/Images/n02110627-affenpinscher/n02110627_4130.jpg'
